# %%
# !pip install pytesseract evaluate tqdm transformers datasets rouge-score accelerate nltk tensorboard jupyter-black py7zr --upgrade
# !pip install bitsandbytes
# !pip install sentencepiece
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting transformers
#   Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 55.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.16.0-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 44.4 MB/s eta 0:00:00
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting accelerate
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.15.1)
# Collecting jupyter-black
#   Downloading jupyter_black-0.3.4-py3-none-any.whl (8.5 kB)
# Collecting py7zr
#   Downloading py7zr-0.20.8-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.23.5)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.19.4)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.1)
# Collecting black>=21 (from jupyter-black)
#   Downloading black-23.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 74.8 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=7 in /usr/local/lib/python3.10/dist-packages (from jupyter-black) (7.34.0)
# Collecting tokenize-rt>=4 (from jupyter-black)
#   Downloading tokenize_rt-5.2.0-py2.py3-none-any.whl (5.8 kB)
# Collecting texttable (from py7zr)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr)
#   Downloading pycryptodomex-3.19.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.7 MB/s eta 0:00:00
# Collecting pyzstd>=0.15.9 (from py7zr)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 33.1 MB/s eta 0:00:00
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr)
#   Downloading pyppmd-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 11.0 MB/s eta 0:00:00
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.5 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.6 MB/s eta 0:00:00
# Collecting brotli>=1.1.0 (from py7zr)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 96.1 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.4.3 (from black>=21->jupyter-black)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black>=21->jupyter-black)
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black>=21->jupyter-black) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black>=21->jupyter-black) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black>=21->jupyter-black) (4.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Collecting jedi>=0.16 (from ipython>=7->jupyter-black)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7->jupyter-black) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2023.11.17)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7->jupyter-black) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7->jupyter-black) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7->jupyter-black) (0.2.12)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=eadd63c65dcc569c81ba70fbec136eb31979b666b4085f179f9a973f54477779
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: texttable, brotli, tokenize-rt, pyzstd, pytesseract, pyppmd, pycryptodomex, pybcj, pyarrow-hotfix, pathspec, mypy-extensions, multivolumefile, jedi, inflate64, dill, rouge-score, responses, py7zr, multiprocess, black, jupyter-black, accelerate, transformers, datasets, evaluate
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed accelerate-0.25.0 black-23.12.1 brotli-1.1.0 datasets-2.16.0 dill-0.3.7 evaluate-0.4.1 inflate64-1.0.0 jedi-0.19.1 jupyter-black-0.3.4 multiprocess-0.70.15 multivolumefile-0.2.3 mypy-extensions-1.0.0 pathspec-0.12.1 py7zr-0.20.8 pyarrow-hotfix-0.6 pybcj-1.0.2 pycryptodomex-3.19.0 pyppmd-1.1.0 pytesseract-0.3.10 pyzstd-0.15.9 responses-0.18.0 rouge-score-0.1.2 texttable-1.7.0 tokenize-rt-5.2.0 transformers-4.36.2
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.41.3.post2-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 15.4 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.41.3.post2
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.2 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

#현재 폴더 경로; 작업 폴더 기준
print(os.getcwd())
# Out:
# /content

# %%
os.chdir("/content/drive/MyDrive/chart2text/FLANT5")

# %%
print(os.getcwd())
# Out:
# /content/drive/MyDrive/chart2text/FLANT5

# %%
import os
import json
def load_dataset():


    pew_dataset_root_path='../dataset/pew_dataset_reduced'
    statista_dataset_root_path='../dataset/statista_dataset_reduced'
    scicap_data_root_path='../dataset/scicap_data_reduced'
    simulated_scatter_root_path='../dataset/simulated_scatter_dataset'

    # pew_dataset_root_path='/Users/dongunyun/study/datascience/chart2text/dataset/pew_dataset'
    # statista_dataset_root_path='/Users/dongunyun/study/datascience/chart2text/dataset/statista_dataset'
    # scicap_data_root_path='/Users/dongunyun/study/datascience/chart2text/dataset/scicap_data'
    # simulated_scatter_root_path='/Users/dongunyun/study/datascience/chart2text/dataset/simulated_scatter_dataset'

    train_dataset=[]
    valid_dataset=[]
    test_dataset=[]

    capspath=os.path.join(simulated_scatter_root_path,'data','train')
    imagepath=os.path.join(simulated_scatter_root_path,'image','train')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            train_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_scatter_root_path,'data','valid')
    imagepath=os.path.join(simulated_scatter_root_path,'image','valid')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            valid_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_scatter_root_path,'data','test')
    imagepath=os.path.join(simulated_scatter_root_path,'image','test')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            test_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    dataset=train_dataset
    # dataset['valid']=valid_dataset
    # dataset['test']=test_dataset
    dataset.extend(test_dataset)
    return dataset

# %%
import os
import json
def load_dataset():



    simulated_scatter_root_path='../dataset/simulated_scatter_dataset_only_test'

    test_dataset=[]

    capspath=os.path.join(simulated_scatter_root_path,'data','test')
    imagepath=os.path.join(simulated_scatter_root_path,'image','test')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            test_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    dataset=test_dataset

    return dataset

# %%
dataset = load_dataset()
print(len(dataset))
import pandas as pd
from datasets import Dataset
df=pd.DataFrame(dataset,columns=['image','text','origin_text'])
data = Dataset.from_pandas(df).train_test_split(test_size=0.9,seed=0)
print(data)
# Out:
# 64
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'text', 'origin_text'],
#         num_rows: 6
#     })
#     test: Dataset({
#         features: ['image', 'text', 'origin_text'],
#         num_rows: 58
#     })
# })

# %%
import pandas as pd
from datasets import Dataset
df=pd.DataFrame(dataset,columns=['image','text','origin_text'])
data = Dataset.from_pandas(df).train_test_split(test_size=0.2,seed=0)
print(data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'text', 'origin_text'],
#         num_rows: 51
#     })
#     test: Dataset({
#         features: ['image', 'text', 'origin_text'],
#         num_rows: 13
#     })
# })

# %%
from datasets import concatenate_datasets
import evaluate
import nltk
import numpy as np
from nltk.tokenize import sent_tokenize
from transformers import DataCollatorForSeq2Seq
from huggingface_hub import HfFolder
from transformers import pipeline
from random import randrange
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments
import os

# %%
MODEL_NAME = "chart2text"  # the name of your model
MODEL_ID = "google/flan-t5-base" # the id of the base model we will train (can be small, base, large, xl, etc.) (the bigger - the more GPU memory you need)
# REPOSITORY_ID = f"{MODEL_ID.split('/')[1]}-{MODEL_NAME}"  # the id of your huggingface repository where the model will be stored
REPOSITORY_ID="./output_long"

NUM_TRAIN_EPOCHS = 4  # number of epochs to train
max_source_length=2048+512
max_target_length=2048+512
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
model = T5ForConditionalGeneration.from_pretrained(MODEL_ID,device_map="auto")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
model.num_parameters()
# Out:
# 247577856

# %%
max_source_length=2048+512
max_target_length=2048+512
def preprocess_function(sample, padding="max_length"):

    def getinputs(cap_path):
        if os.path.isfile(cap_path):
            with open(cap_path) as f:
                json_object = json.load(f)
            if 'description' in json_object:
                if "This scatterplot is a chart showing the distribution of values over time" in json_object["description"]:
                    query="describe this data distribution about trend and its abnormalities"
                elif "This scatterplot is a graph that represents the relationship between" in json_object["description"]:
                    query="describe this data distribution about correlation and its abnormalities"
                elif "This scatterplot shows the clustering results of groups between" in json_object["description"]:
                    query="describe this data distribution about differences and clustering and its abnormalities"
                else:
                    query="describe this data distribution"
            else:
                query="describe this data distribution"
        else:
            query="describe this data distribution"


        inputs = str(json_object['features']) + "Look at the data table above, " + query + "\n\n"
        return inputs

    inputs = [getinputs(input) for input in sample['origin_text']]
    model_inputs = tokenizer(
        inputs, max_length=max_source_length, padding=padding, truncation=True
    )

    labels = tokenizer(
        text_target=sample["text"],
        max_length=max_target_length,
        padding=padding,
        truncation=True,
    )

    if padding == "max_length":
        labels["input_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label]
            for label in labels["input_ids"]
        ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs


tokenized_dataset = data.map(
    preprocess_function, batched=True, remove_columns=["image"]
)
# Out:
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
# Map:   0%|          | 0/58 [00:00<?, ? examples/s]

# %%
# metric
metric = evaluate.load("rouge")
nltk.download("punkt")


# postprocess text
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]

    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]

    return preds, labels


# compute metrics
def compute_metrics(eval_preds):
    preds, labels = eval_preds

    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(
        predictions=decoded_preds, references=decoded_labels, use_stemmer=True
    )
    result = {k: round(v * 100, 4) for k, v in result.items()}
    prediction_lens = [
        np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds
    ]
    result["gen_len"] = np.mean(prediction_lens)
    return result
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
label_pad_token_id = -100

data_collator = DataCollatorForSeq2Seq(
    tokenizer, model=model, label_pad_token_id=label_pad_token_id, pad_to_multiple_of=8
)

# %%
# Define training args
training_args = Seq2SeqTrainingArguments(
    # training parameters
    output_dir=REPOSITORY_ID,
    overwrite_output_dir = 'True',
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    predict_with_generate=True,
    fp16=False,  # Overflows with fp16
    learning_rate=5e-5,
    num_train_epochs=20,
    # logging & evaluation strategies
    logging_dir=f"{REPOSITORY_ID}/logs",
    logging_strategy="steps",
    logging_steps=500,
    evaluation_strategy="epoch",

    save_total_limit=1,

    report_to="tensorboard",

    save_strategy="epoch",
    load_best_model_at_end=True,

    disable_tqdm=False,
)

# Create Trainer instance
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    compute_metrics=compute_metrics,
)

# %%
# Start training
trainer.train()
# Out:
#     <div>
#
#       <progress value='117' max='59260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  117/59260 01:34 < 13:27:49, 1.22 it/s, Epoch 0.04/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='4025' max='59260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 4025/59260 1:06:02 < 15:06:41, 1.02 it/s, Epoch 1.36/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.883300</td>
#       <td>0.799605</td>
#       <td>24.491700</td>
#       <td>18.067600</td>
#       <td>23.282300</td>
#       <td>24.021600</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1355: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-635967aca760> in <cell line: 2>()
#       1 # Start training
# ----> 2 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1535                 hf_hub_utils.enable_progress_bars()
#    1536         else:
# -> 1537             return inner_training_loop(
#    1538                 args=args,
#    1539                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1900
#    1901                     # Optimizer step
# -> 1902                     self.optimizer.step()
#    1903                     optimizer_was_run = not self.accelerator.optimizer_step_was_skipped
#    1904                     if optimizer_was_run:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/optimizer.py in step(self, closure)
#     143                 self._accelerate_step_called = False
#     144             else:
# --> 145                 self.optimizer.step(closure)
#     146
#     147     def _switch_parameters(self, parameters_map):
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      66                 instance._step_count += 1
#      67                 wrapped = func.__get__(instance, cls)
# ---> 68                 return wrapped(*args, **kwargs)
#      69
#      70             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     371                             )
#     372
# --> 373                 out = func(*args, **kwargs)
#     374                 self._optimizer_step_code()
#     375
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      74             torch.set_grad_enabled(self.defaults['differentiable'])
#      75             torch._dynamo.graph_break()
# ---> 76             ret = func(self, *args, **kwargs)
#      77         finally:
#      78             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adamw.py in step(self, closure)
#     182             )
#     183
# --> 184             adamw(
#     185                 params_with_grad,
#     186                 grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adamw.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     333         func = _single_tensor_adamw
#     334
# --> 335     func(
#     336         params,
#     337         grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adamw.py in _multi_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     597                 exp_avg_sq_sqrt = torch._foreach_sqrt(device_max_exp_avg_sqs)
#     598             else:
# --> 599                 exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
#     600
#     601             torch._foreach_div_(exp_avg_sq_sqrt, bias_correction2_sqrt)
#
# KeyboardInterrupt:

# %%
save_path = os.path.join('./output_short/', 'summary_chart-checkpoint-last')
model.save_pretrained(save_path, from_pt=True)
tokenizer.save_pretrained(save_path, from_pt=True)

# %%
MODEL_NAME = "chart2text"  # the name of your model
MODEL_ID = "/content/drive/MyDrive/chart2text/FLANT5/output_short/checkpoint-8892" # the id of the base model we will train (can be small, base, large, xl, etc.) (the bigger - the more GPU memory you need)
# MODEL_ID ="/content/drive/MyDrive/chart2text/FLANT5/output_short/checkpoint-11856"
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
model = T5ForConditionalGeneration.from_pretrained(MODEL_ID,device_map="auto")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
idx=1

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'strategie', 's', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", 'etc', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", '*', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '4', '000', "'", ',', '', "'", 'me', 'an', "'", ':', '12', '70', '.', '77', '147', '71', '365', '71', ',', '', "'", 's', 't', 'd', "'", ':', '16', '3.1', '3', '78', '74', '28', '75', '42', '47', ',', '', "'", 'media', 'n', "'", ':', '', '127', '1.6', '08', '210', '500', '92', '66', ',', '', "'", 'min', "'", ':', '8', '42', '.', '37', '160', '66', '70', '39', '3,', '', "'", 'max', "'", ':', '17', '96', '.', '90', '28', '97', '47', '31', '177', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.0', '79', '64', '95', '69', '45', '2', '144', '78', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '0.4', '000', '52', '500', '39', '180', '36', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '11', '68', '.', '30', '58', '65', '205', '83', '17', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '137', '0.6', '365', '316', '76', '138', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 's', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '3', 'aff', 'b', 'c', "'", ',', '', "'", 'me', 'an', "'", ':', '', '125', '8.0', '29', '93', '25', '46', '100', '3,', '', "'", 's', 't', 'd', "'", ':', '14', '5.1', '63', '17', '10', '74', '192', '4,', '', "'", 'media', 'n', "'", ':', '', '126', '4.4', '440', '38', '57', '00', '186', ',', '', "'", 'min', "'", ':', '', '83', '6.7', '32', '26', '80', '350', '67', '8,', '', "'", 'max', "'", ':', '15', '97', '.', '09', '27', '17', '52', '199', '6,', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.2', '44', '28', '79', '64', '25', '25', '243', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.1', '41', '116', '27', '24', '126', '44', '68', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':',
',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.4', '42', '925', '28', '78', '30', '50', '89', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.0', '68', '04', '64', '47', '720', '68', '96', '8,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '105', '1.1', '184', '540', '90', '71', '09', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-10', '35', '.', '86', '280', '77', '97', '36', '42', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'und', 'e', 'a', 'd', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'a', '400', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-10', '43', '.', '62', '99', '10', '404', '09', '38', ',', '', "'", 's', 't', 'd', "'", ':', '9.', '166', '11', '22', '94', '82', '83', '96', ',', '', "'", 'media', 'n', "'", ':', '', '-', '104', '3.6', '03', '71', '28', '65', '63', '44', ',', '', "'", 'min', "'", ':', '', '-10', '65', '.', '67', '420', '66', '66', '49', '54', ',', '', "'", 'max', "'", ':', '', '-10', '23', '.', '67', '46', '104', '38', '78', '93', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.0', '65', '96', '55', '124', '88', '43', '61', '1,', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.3', '37', '62', '19', '18', '65', '105', '65', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-10', '50', '.', '88', '98', '29', '85', '75', '98', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-10', '36', '.', '08', '78', '46', '110', '25', '93', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'и', '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', '80', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-10', '41', '.', '54', '147', '64', '18', '96', '59', ',', '', "'", 's', 't', 'd', "'", ':', '9.', '98', '53', '89', '140', '67', '33', '55', ',', '', "'", 'media', 'n', "'", ':', '', '-10', '42', '.', '106', '36', '88', '28', '102', '4,', '', "'", 'min', "'", ':', '', '-10', '58', '.', '37', '89', '47', '98', '800', '68', ',', '', "'", 'max', "'", ':', '', '-10', '22', '.', '42', '65', '73', '360', '54', '76', ',', '',  ...
# ["This scatterplot illustrates the relationship between 'Zambia' and 'continuance', with a mean of -1043.706 and a standard deviation of 10.816 for 'Zambia', and a mean of -305.707 and a standard deviation of 21.798 for 'continuance'. There are a total of 9 groups, and the correlation coefficient is -0.01, indicating no linear relationship between the two data sets."]
# 'This scatterplot illustrates the relationship between "Zambia" and "continuance," with the data points for "Zambia" having a mean of -1042.598 and a standard deviation of 9.927, and the data points for "continuance" having a mean of -303.088 and a standard deviation of 24.733. There are a total of 9 groups, and the correlation coefficient of this scatter plot is -0.003, indicating no linear relationship between the two datasets.'

# %%
idx=3

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'trans', 'it', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", 'Ch', 'i', 'cken', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'cre', 'ation', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', 'c', '3', 'f', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '6', '97', '.', '19', '33', '23', '94', '90', '131', ',', '', "'", 's', 't', 'd', "'", ':', '', '420', '.', '97', '79', '39', '42', '78', '97', '24', ',', '', "'", 'media', 'n', "'", ':', '', '68', '4.0', '79', '74', '67', '44', '153', ',', '', "'", 'min', "'", ':', '', '-', '177', '.', '07', '06', '22', '71', '75', '98', '67', ',', '', "'", 'max', "'", ':', '150', '3.2', '58', '02', '29', '45', '38', '52', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.00', '92', '2', '69', '28', '333', '58', '99', '76', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.8', '44', '18', '164', '29', '47', '74', '38', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '36', '3.7', '24', '188', '74', '45', '126', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '10', '18', '.', '46', '950', '16', '26', '57', '65', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', 'f', 'a', "'", ',', '', "'", 'me', 'an', "'", ':', '7', '13', '.', '48', '28', '95', '57', '49', '196', ',', '', "'", 's', 't', 'd', "'", ':', '4', '63', '.', '0', '63', '17', '47', '35', '13', '57', ',', '', "'", 'media', 'n', "'", ':', '', '78', '0.8', '14', '80', '36', '93', '36', '77', ',', '', "'", 'min', "'", ':', '', '-', '52', '4.5', '35', '93', '17', '34', '42', '23', ',', '', "'", 'max', "'", ':', '', '153', '6.0', '70', '54', '48', '28', '37', '25', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.4', '89', '22', '88', '03', '9001', '68', '43', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.1', '27', '410', '99', '05', '165', '46', '8,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '43', '1.3', '92', '08', '27', '45', '233', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '100', '8', '.99', '13', '22', '370', '57', '11', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'qui', 'cker', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', 'c', '3', 'f', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-4', '12.', '23', '114', '27', '90', '24', '68', '5,', '', "'", 's', 't', 'd', "'", ':', '50', '4.6', '86', '48', '29', '13', '53', '27', ',', '', "'", 'media', 'n', "'", ':', '', '-4', '54', '.', '840', '44', '89', '34', '37', '84', ',', '', "'", 'min', "'", ':', '', '-13', '78', '.', '95', '23', '61', '49', '42', '36', '4,', '', "'", 'max', "'", ':', '8', '15', '.', '43', '29', '77', '98', '119', '98', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '28', '27', '555', '5000', '62', '68', '73', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.2', '96', '23', '148', '15', '38', '99', '37', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-7', '76', '.', '98', '95', '69', '04', '93', '46', '3,', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-', '38', '.', '206', '23', '68', '164', '79', '88', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'd', 'rank', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'b', 'd', '0000', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-21', '5.6', '59', '01', '570', '55', '91', '1,', '', "'", 's', 't', 'd', "'", ':', '4', '96', '.', '81', '87', '53', '37', '75', '69', '1,', '', "'", 'media', 'n', "'", ':', '', '-', '29', '0.0', '90', '235', '06', '72', '97', '33', ',', '', "'", 'min', "'", ':', '', '-12', '98', '.', '07', '55', '72', '176', '59', '68', ',', '', "'", 'max', "'", ':', '11', '20', '.', '199', '89', '04', '62', '13', '37', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.4', '58', '55', '59', '79', '8 ...
# ["This scatterplot displays the clustering results of groups between 'transit' and 'Chicken' relationships. The data points for 'transit' typically have a mean of -351.906 and a standard deviation of 591.052, while the data points for 'Chicken' typically have a mean of 1742.551 and a standard deviation of 591.916. There are a total of six groups, and the color names of other clusters that differ in data from the main cluster are skyblue. Additionally, the group names of other clusters that differ in data from the main cluster are 'creation'."]
# '"This scatterplot displays the clustering results for the \'transit\' and \'Chicken\' relationships. The data points for \'transit\' typically have a mean of 56.534 and a standard deviation of 666.213, while the data points for \'Chicken\' have a mean of 1180.875 and a standard deviation of 480.669. There are a total of 6 clusters, each with a unique color name: skyblue, blue, creation, and メ. Note that the main cluster is represented by the most prominent color."'

# %%
idx=4

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '', "'", 'date', 'time', "'", ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", '—', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '02', '20', ':', '23', ':', '2', '4.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-15', '19', ':', '27', ':', '56', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'pur', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'e', '8', 'f', 'f', '0', 'f', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '03', '20', ':', '42', ':', '17', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-', '09', '06', ':', '37', ':', '17', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Fel', 'l', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'd', '500', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-25', '17', ':', '28', ':', '1', '5.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-30', '19', ':', '11', ':', '1', '5.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'mus', 'lim', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', '57', 'f', 'f', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-19', '17', ':', '51', ':', '58', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '202', '4-0', '1-0', '2', '10', ':', '07', ':', '58', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'key', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'a', '400', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-14', '11', ':', '19', ':', '0', '0.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-', '31', '21', ':', '53', ':', '16', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'd', 'rug', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', 'f', 'a', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '06', '22', ':', '24', ':', '48', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-14', '18', ':', '44', ':', '4', '4.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'P', 'atty', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'b', 'c', 'f', 'f', '3', 'a', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-11', '-24', '', '05', ':', '45', ':', '28', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-10', '13', ':', '54', ':', '28', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'stream', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', 'b', 'd', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '05', '22', ':', '08', ':', '39', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-24', '06', ':', '34', ':', '09.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'col', 'l', 'usion', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'b', 'd', '0000', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-11', '-22', '15', ':', '46', ':', '08.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-', '08', '19', ':', '12', ':', '2', '0.000', "'", '<unk>', '],', '', "'", 'y', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'me', 'an', "'", ':', '8', '33', '.', '800', '73', '124', '73', '36', '4,', '', "'", 's', 't', 'd', "'", ':', '19.', '66', '2002', '94', '19', '119', '68', ',', '' ...
# ['"This scatterplot shows the distribution of values over time for \'—\'. The data typically has a mean of 790.041 and a standard deviation of 0.541, and it appears to decrease at a negative slope. There are ten distinct groups, and two of them have unique slopes compared to the others. Specifically, the blue \'\' group has a slope difference of approximately 13% relative to the other groups, while the skyblue \'drug\' group has a slope difference of around 13%."']
# 'This scatterplot shows the distribution of values over time for a specific dataset, with a mean of 801.752 and a standard deviation of 5.686. The chart indicates that the values have a positive slope and continue to increase over time. There are nine groups in total, and one group (marked in red as "collusion") has a distinct trend different from the others, with a slope difference of approximately 19%.'

# %%
idx=5

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'm', 'is', 'take', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", 'de', 'c', 'line', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'pre', 'mat', 'ure', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'a', '0', 'e', '00', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '33', '2.3', '26', '58', '45', '29', '33', '214', ',', '', "'", 's', 't', 'd', "'", ':', '0.', '41', '900', '69', '124', '65', '40', '98', '3,', '', "'", 'media', 'n', "'", ':', '', '-3', '32', '.', '28', '83', '27', '10', '94', '16', '97', ',', '', "'", 'min', "'", ':', '', '-', '333', '.', '19', '73', '42', '146', '16', '07', ',', '', "'", 'max', "'", ':', '', '-3', '31', '.', '23', '85', '80', '77', '28', '42', '17', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.1', '350', '65', '94', '80', '92', '76', '87', '3,', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.3', '33', '88', '78', '118', '53', '31', '77', '3,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '33', '2.6', '06', '79', '18', '75', '76', '89', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-3', '32', '.', '03', '176', '13', '57', '03', '36', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 's', 'par', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', '8', 'd', 'f', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '330', '.', '23', '76', '97', '93', '94', '25', '2,', '', "'", 's', 't', 'd', "'", ':', '0.', '43', '54', '85', '89', '28', '154', '30', '2,', '', "'", 'media', 'n', "'", ':', '', '-', '33', '0.2', '76', '275', '850', '66', '8,', '', "'", 'min', "'", ':', '', '-3', '31', '.', '02', '97', '211', '62', '202', '86', ',', '', "'", 'max', "'", ':', '', '-3', '29', '.', '38', '52', '15', '12', '404', '69', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '136', '63', '300', '50', '56', '01', '264', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.8', '48', '316', '350', '28', '45', '6', '99', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '33', '0.5', '25', '24', '38', '43', '340', '26', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-3', '29', '.', '866', '39', '85', '2', '26', '63', '36', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'h', 'on', 'our', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '4', '000', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '33', '3.6', '925', '36', '38', '53', '540', '6,', '', "'", 's', 't', 'd', "'", ':', '', '0.5', '2012', '64', '34', '83', '96', '58', '6,', '', "'", 'media', 'n', "'", ':', '', '-', '333', '.', '63', '85', '74', '999', '22', '19', '3,', '', "'", 'min', "'", ':', '', '-3', '35', '.', '09', '05', '13', '115', '198', '5,', '', "'", 'max', "'", ':', '', '-3', '32', '.', '63', '150', '34', '116', '42', '4,', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.4', '40', '89', '64', '38', '82', '34', '15', '17', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '0.', '169', '365', '49', '73', '174', '63', '2,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-3', '34', '.', '02', '28', '79', '600', '73', '47', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-', '333', '.', '34', '88', '06', '16', '32', '85', '13', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Comm', 'on', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '66', 'f', 'f', '91', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '33', '1.6', '18', '58', '89', '74', '14', '07', ',', '', "'", 's', 't', 'd', "'", ':', '0.', '44', '77', '48', '90', '950', '68', '16', '1,', '', "'", 'media', 'n', "'", ':', '', '-', '33', '1.6', '225', '99', '81', '80', '97', '06', ',', '', "'", 'min', "'", ':', '', '-', '33', '2.4', '42', '305', '127', '98', '36', ',', '', "'", 'max', "'", ':', '', '-', '330', '.', '28', '76', '89', '2 ...
# ["This scatterplot illustrates the relationship between'mistake' and 'decline', with a mean of -332.706 and a standard deviation of 0.562 for'mistake', and a mean of 735.717 and a standard deviation of 4.464 for 'decline'. There are a total of 8 groups, and the correlation coefficient is -0.01, indicating no linear relationship between the two data sets."]
# "This scatterplot illustrates the relationship between 'mistake' and 'decline', with a mean of -331.314 and a standard deviation of 1.526 for the 'mistake' data, and a mean of 735.624 and a standard deviation of 4.926 for the 'decline' data. There are a total of 8 groups, and the correlation coefficient is 0.042. Since the correlation coefficient is less than 0.3, there is no strong linear relationship between the two datasets."

# %%
idx=6

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '', "'", 'date', 'time', "'", ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'Mar', 'th', 'a', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'cast', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0', 'f', 'f', '8', 'e', '8', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-13', '03', ':', '50', ':', '2', '0.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '24', '-01', '-04', '09', ':', '13', ':', '2', '4.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Qu', 'e', 'en', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-25', '02', ':', '40', ':', '5', '0.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '24', '-01', '-16', '12', ':', '21', ':', '4', '4.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'author', 'ities', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '3', 'aff', 'b', 'c', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '23', '08', ':', '59', ':', '2', '3.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '24', '-01', '-14', '01', ':', '17', ':', '03.', '000', "'", '<unk>', '],', '', "'", 'y', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'cast', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0', 'f', 'f', '8', 'e', '8', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-5', '19', '.', '93', '17', '103', '08', '68', '85', ',', '', "'", 's', 't', 'd', "'", ':', '8', '7.5', '160', '28', '47', '70', '39', '19', ',', '', "'", 'media', 'n', "'", ':', '', '-', '52', '0.6', '08', '74', '75', '47', '62', '86', ',', '', "'", 'min', "'", ':', '', '-7', '06.', '48', '98', '960', '62', '59', '75', ',', '', "'", 'max', "'", ':', '', '-', '32', '4.8', '89', '49', '125', '4', '15', '206', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '10', '154', '56', '38', '90', '205', '32', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.6', '95', '700', '126', '102', '83', '48', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-5', '84', '.', '950', '232', '640', '17', '39', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-4', '59', '.', '26', '53', '64', '70', '80', '83', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Qu', 'e', 'en', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f',
 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'a', '400', "'", ',', '', "'", 'me', 'an', "'", ':', '12', '06.', '290', '92', '86', '26', '211', ',', '', "'", 's', 't', 'd', "'", ':', '16', '4.8', '69', '74', '52', '17', '305', '88', ',', '', "'", 'media', 'n', "'", ':', '', '119', '1.7', '30', '195', '27', '46', '64', '8,', '', "'", 'min', "'", ':', '', '91', '2.3', '39', '42', '290', '177', '81', ',', '', "'", 'max', "'", ':', '14', '68', '.', '49', '80', '83', '58', '52', '65', '5,', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.1', '350', '85', '224', '09', '63', '186', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-1', '.', '08', '30', '76', '46', '224', '290', '83', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '10', '84', '.', '104', '88', '43', '31', '30', '56', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '13', '49', '.', '30', '74', '139', '360', '45', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Disc', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0', 'f', 'f', '8', 'e', '8', "'", ',', '', "'", 'me', 'an', "'", ':', '12', '22', '.', '88', '950', '59', '18', '23', '66', ',', '', "'", 's', 't', 'd', "'", ':', '13', '5.5', '401', '960', '47', '80', '90', '5,', '', "'", 'media', 'n', "'", ':', '12', '27', '.', '80', '62', '98', '27', '77', '82', '4,', '', "'", 'min', "'", ':', '', '97', '3.4', '74', '125', '69', '53', '26', '8,', '', "'", 'max', "'", ':', '14', '85', '.', '93', '89', '55', '235', '58', '47', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.0', '91', '145', '28', '79', '12', '119', '86', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.8', '69', '109', '30', '95', '86', '43', '95', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '11', '04.', '243', '59', '77', '25', '189', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '13', '16', '.', '28', '270', '89', '60', '55', '57', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'cham', 'pion', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', '8', 'd', 'f', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '', '118', '5.0', '68', '72', '88', '15', '129', '6,', '', "'", 's', 't', 'd', "'", ':', '350', '.', '34', '65', '179', '74', '22', '39', ',', '', "'", 'media', 'n', "'", ':', '12', '14', '.', '50', '70', '99', '140', '57', '96', ',', '', "'", 'min', "'", ':', '5', '80', '.', '125', '79', '42', '67', '28', '26', ',', '', "'", 'max', "'", ':', '', '178', '8.5', '26', '34', '84', '56', '49', '37', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.0', '60', '17', '3', '77', '106', '17', '123', '1,', '', "'", 'kur', 'to', 's', 'is', "'", ':', '',  ...
# ['This scatterplot illustrates the relationship between \'nav>\' and \']",\'\', with a mean of 1218.507 and a standard deviation of 239.069 for \'nav>\', and a mean of -1670.803 and a standard deviation of 348.438 for \']",\'\'. There are a total of 9 groups, and the correlation coefficient is -0.01, indicating no linear relationship between the two data sets.']
# 'This scatterplot illustrates the relationship between \'<nav>\' and \']",\' with a mean of 1204.94 and a standard deviation of 255.629 for \'<nav>\', and a mean of -1633.732 and a standard deviation of 282.567 for \']",\'. There are a total of 9 groups, and the correlation coefficient is 0.84, indicating a strong linear relationship between the two data sets.'

# %%
MODEL_NAME = "chart2text"  # the name of your model
# MODEL_ID = "/content/drive/MyDrive/chart2text/FLANT5/output_short/checkpoint-8892" # the id of the base model we will train (can be small, base, large, xl, etc.) (the bigger - the more GPU memory you need)
MODEL_ID ="/content/drive/MyDrive/chart2text/FLANT5/output_short/checkpoint-11856"
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
model = T5ForConditionalGeneration.from_pretrained(MODEL_ID,device_map="auto")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
idx=1

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'strategie', 's', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", 'etc', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", '*', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f',
import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'Z', 'ambi', 'a', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", 'continu', 'ance', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'vent', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '66', 'f', 'f', '91', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '104', '2.0', '53', '187', '92', '49', '197', ',', '', "'", 's', 't', 'd', "'", ':', '10.', '69', '28', '270', '56', '08', '49', '4,', '', "'", 'media', 'n', "'", ':', '', '-10', '42', '.', '73', '69', '07', '99', '430', '8,', '', "'", 'min', "'", ':', '', '-', '107', '0.0', '850', '78', '86', '89', '28', '6,', '', "'", 'max', "'", ':', '', '-', '102', '0.5', '96', '172', '53', '66', '207', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.2', '09', '35', '90', '49', '2', '204', '17', '95', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.2', '31', '43', '86', '95', '60', '64', '73', '57', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-10', '50', '.', '31', '75', '44', '82', '13', '97', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-10', '33', '.', '52', '37', '35', '49', '93', '36', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'N', 'eed', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', 'c', '3', 'f', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-10', '42', '.', '64', '43', '124', '78', '45', '91', ',', '', "'", 's', 't', 'd', "'", ':', '10.', '8', '15', '05', '28', '44', '90', '25', '14', ',', '', "'", 'media', 'n', "'", ':', '', '-', '104', '3.9', '81', '70', '26', '39', '75', '93', ',', '', "'", 'min', "'", ':', '', '-', '106', '1.7', '800', '79', '82', '81', '6,', '', "'", 'max', "'", ':', '', '-', '101', '4.0', '192', '94', '57', '10', '777', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.4', '42', '925', '28', '78', '30', '50', '89', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.0', '68', '04', '64', '47', '720', '68', '96', '8,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '105', '1.1', '184', '540', '90', '71', '09', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-10', '35', '.', '86', '280', '77', '97', '36', '42', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'und', 'e', 'a', 'd', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'a', '400', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-10', '43', '.', '62', '99', '10', '404', '09', '38', ',', '', "'", 's', 't', 'd', "'", ':', '9.', '166', '11', '22', '94', '82', '83', '96', ',', '', "'", 'media', 'n', "'", ':', '', '-', '104', '3.6', '03', '71', '28', '65', '63', '44', ',', '', "'", 'min', "'", ':', '', '-10', '65', '.', '67', '420', '66', '66', '49', '54', ',', '', "'", 'max', "'", ':', '', '-10', '23', '.', '67', '46', '104', '38', '78', '93', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.0', '65', '96', '55', '124', '88', '43', '61', '1,', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.3', '37', '62', '19', '18', '65', '105', '65', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-10', '50', '.', '88', '98', '29', '85', '75', '98', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-10', '36', '.', '08', '78', '46', '110', '25', '93', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'и', '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', '80', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-10', '41', '.', '54', '147', '64', '18', '96', '59', ',', '', "'", 's', 't', 'd', "'", ':', '9.', '98', '53', '89', '140', '67', '33', '55', ',', '', "'", 'media', 'n', "'", ':', '', '-10', '42', '.', '106', '36', '88', '28', '102', '4,', '', "'", 'min', "'", ':', '', '-10', '58', '.', '37', '89', '47', '98', '800', '68', ',', '', "'", 'max', "'", ':', '', '-10', '22', '.', '42', '65', '73', '360', '54', '76', ',', '',  ...
# ["This scatterplot illustrates the relationship between 'Zambia' and 'continuance', with a mean of -1044.609 and a standard deviation of 10.818 for 'Zambia', and a mean of -305.798 and a standard deviation of 21.798 for 'continuance'. There are a total of 9 groups, and the correlation coefficient is 0.026, indicating no linear relationship between the two datasets."]
# 'This scatterplot illustrates the relationship between "Zambia" and "continuance," with the data points for "Zambia" having a mean of -1042.598 and a standard deviation of 9.927, and the data points for "continuance" having a mean of -303.088 and a standard deviation of 24.733. There are a total of 9 groups, and the correlation coefficient of this scatter plot is -0.003, indicating no linear relationship between the two datasets.'

# %%
idx=3

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 
',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.4', '58', '55', '59', '79', '8 ...
# ["This scatterplot displays the clustering results of groups between 'transit' and 'Chicken' relationships. The data points for 'transit' typically have a mean of -354.663 and a standard deviation of 593.645, while the data points for 'Chicken' typically have a mean of 1456.532 and a standard deviation of 596.432. There are a total of 7 groups, and the color names of other clusters that differ in data from the main cluster are skyblue. The group names of other clusters that differ in data from the main cluster are 'creation'."]
# '"This scatterplot displays the clustering results for the \'transit\' and \'Chicken\' relationships. The data points for \'transit\' typically have a mean of 56.534 and a standard deviation of 666.213, while the data points for \'Chicken\' have a mean of 1180.875 and a standard deviation of 480.669. There are a total of 6 clusters, each with a unique color name: skyblue, blue, creation, and メ. Note that the main cluster is represented by the most prominent color."'

# %%
idx=4

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '', "'", 'date', 'time', "'", ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", '—', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '02', '20', ':', '23', ':', '2', '4.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-15', '19', ':', '27', ':', '56', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'pur', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'e', '8', 'f', 'f', '0', 'f', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '03', '20', ':', '42', ':', '17', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-', '09', '06', ':', '37', ':', '17', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Fel', 'l', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'd', '500', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-25', '17', ':', '28', ':', '1', '5.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-30', '19', ':', '11', ':', '1', '5.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'mus', 'lim', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', '57', 'f', 'f', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-19', '17', ':', '51', ':', '58', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '202', '4-0', '1-0', '2', '10', ':', '07', ':', '58', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'key', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'a', '400', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-14', '11', ':', '19', ':', '0', '0.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-', '31', '21', ':', '53', ':', '16', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'd', 'rug', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', 'f', 'a', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '06', '22', ':', '24', ':', '48', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-14', '18', ':', '44', ':', '4', '4.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'P', 'atty', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'b', 'c', 'f', 'f', '3', 'a', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-11', '-24', '', '05', ':', '45', ':', '28', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-10', '13', ':', '54', ':', '28', '.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'stream', 's', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', 'b', 'd', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '05', '22', ':', '08', ':', '39', '.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-24', '06', ':', '34', ':', '09.', '000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'col', 'l', 'usion', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'b', 'd', '0000', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-11', '-22', '15', ':', '46', ':', '08.', '000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '23', '-12', '-', '08', '19', ':', '12', ':', '2', '0.000', "'", '<unk>', '],', '', "'", 'y', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'me', 'an', "'", ':', '8', '33', '.', '800', '73', '124', '73', '36', '4,', '', "'", 's', 't', 'd', "'", ':', '19.', '66', '2002', '94', '19', '119', '68', ',', '' ...
# ["This scatterplot shows the distribution of values over time for '—'. The data typically has a mean of 799.572 and a standard deviation of 2.741, and it appears to be increasing at a positive slope. There are ten distinct groups, and two of them have unique trends compared to the others. Specifically, the blue '' group has a slope difference of approximately 16% relative to the other groups, while the blue 'drug' group has a slope difference of around 13%."]
# 'This scatterplot shows the distribution of values over time for a specific dataset, with a mean of 801.752 and a standard deviation of 5.686. The chart indicates that the values have a positive slope and continue to increase over time. There are nine groups in total, and one group (marked in red as "collusion") has a distinct trend different from the others, with a slope difference of approximately 19%.'

# %%
idx=5

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'm', 'is', 'take', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", 'de', 'c', 'line', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'pre', 'mat', 'ure', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'a', '0', 'e', '00', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '33', '2.3', '26', '58', '45', '29', '33', '214', ',', '', "'", 's', 't', 'd', "'", ':', '0.', '41', '900', '69', '124', '65', '40', '98', '3,', '', "'", 'media', 'n', "'", ':', '', '-3', '32', '.', '28', '83', '27', '10', '94', '16', '97', ',', '', "'", 'min', "'", ':', '', '-', '333', '.', '19', '73', '42', '146', '16', '07', ',', '', "'", 'max', "'", ':', '', '-3', '31', '.', '23', '85', '80', '77', '28', '42', '17', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.1', '350', '65', '94', '80', '92', '76', '87', '3,', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.3', '33', '88', '78', '118', '53', '31', '77', '3,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '33', '2.6', '06', '79', '18', '75', '76', '89', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-3', '32', '.', '03', '176', '13', '57', '03', '36', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 's', 'par', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', '8', 'd', 'f', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '330', '.', '23', '76', '97', '93', '94', '25', '2,', '', "'", 's', 't', 'd', "'", ':', '0.', '43', '54', '85', '89', '28', '154', '30', '2,', '', "'", 'media', 'n', "'", ':', '', '-', '33', '0.2', '76', '275', '850', '66', '8,', '', "'", 'min', "'", ':', '', '-3', '31', '.', '02', '97', '211', '62', '202', '86', ',', '', "'", 'max', "'", ':', '', '-3', '29', '.', '38', '52', '15', '12', '404', '69', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '136', '63', '300', '50', '56', '01', '264', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.8', '48', '316', '350', '28', '45', '6', '99', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '33', '0.5', '25', '24', '38', '43', '340', '26', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-3', '29', '.', '866', '39', '85', '2', '26', '63', '36', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'h', 'on', 'our', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '4', '000', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '33', '3.6', '925', '36', '38', '53', '540', '6,', '', "'", 's', 't', 'd', "'", ':', '', '0.5', '2012', '64', '34', '83', '96', '58', '6,', '', "'", 'media', 'n', "'", ':', '', '-', '333', '.', '63', '85', '74', '999', '22', '19', '3,', '', "'", 'min', "'", ':', '', '-3', '35', '.', '09', '05', '13', '115', '198', '5,', '', "'", 'max', "'", ':', '', '-3', '32', '.', '63', '150', '34', '116', '42', '4,', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.4', '40', '89', '64', '38', '82', '34', '15', '17', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '0.', '169', '365', '49', '73', '174', '63', '2,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-3', '34', '.', '02', '28', '79', '600', '73', '47', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-', '333', '.', '34', '88', '06', '16', '32', '85', '13', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Comm', 'on', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '66', 'f', 'f', '91', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '33', '1.6', '18', '58', '89', '74', '14', '07', ',', '', "'", 's', 't', 'd', "'", ':', '0.', '44', '77', '48', '90', '950', '68', '16', '1,', '', "'", 'media', 'n', "'", ':', '', '-', '33', '1.6', '225', '99', '81', '80', '97', '06', ',', '', "'", 'min', "'", ':', '', '-', '33', '2.4', '42', '305', '127', '98', '36', ',', '', "'", 'max', "'", ':', '', '-', '330', '.', '28', '76', '89', '2 ...
# ["This scatterplot illustrates the relationship between'mistake' and 'decline', with a mean of -331.618 and a standard deviation of 0.562 for the'mistake' data, and a mean of 735.617 and a standard deviation of 4.464 for the 'decline' data. There are a total of 8 groups, and the correlation coefficient is 0.045, indicating no linear relationship between the two datasets."]
# "This scatterplot illustrates the relationship between 'mistake' and 'decline', with a mean of -331.314 and a standard deviation of 1.526 for the 'mistake' data, and a mean of 735.624 and a standard deviation of 4.926 for the 'decline' data. There are a total of 8 groups, and the correlation coefficient is 0.042. Since the correlation coefficient is less than 0.3, there is no strong linear relationship between the two datasets."

# %%
idx=6

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '', "'", 'date', 'time', "'", ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'Mar', 'th', 'a', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'cast', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0', 'f', 'f', '8', 'e', '8', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-13', '03', ':', '50', ':', '2', '0.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '24', '-01', '-04', '09', ':', '13', ':', '2', '4.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Qu', 'e', 'en', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-25', '02', ':', '40', ':', '5', '0.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '24', '-01', '-16', '12', ':', '21', ':', '4', '4.000', "'", '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'author', 'ities', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '3', 'aff', 'b', 'c', "'", ',', '', "'", 'min', "'", ':', '', "'", '20', '23', '-12', '-', '23', '08', ':', '59', ':', '2', '3.000', "'", ',', '', "'", 'max', "'", ':', '', "'", '20', '24', '-01', '-14', '01', ':', '17', ':', '03.', '000', "'", '<unk>', '],', '', "'", 'y', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'cast', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0', 'f', 'f', '8', 'e', '8', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-5', '19', '.', '93', '17', '103', '08', '68', '85', ',', '', "'", 's', 't', 'd', "'", ':', '8', '7.5', '160', '28', '47', '70', '39', '19', ',', '', "'", 'media', 'n', "'", ':', '', '-', '52', '0.6', '08', '74', '75', '47', '62', '86', ',', '', "'", 'min', "'", ':', '', '-7', '06.', '48', '98', '960', '62', '59', '75', ',', '', "'", 'max', "'", ':', '', '-', '32', '4.8', '89', '49', '125', '4', '15', '206', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '10', '154', '56', '38', '90', '205', '32', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.6', '95', '700', '126', '102', '83', '48', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-5', '84', '.', '950', '232', '640', '17', '39', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-4', '59', '.', '26', '53', '64', '70', '80', '83', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'Qu', 'e', 'en', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '510', '.', '67', '430', '06', '6000', '34', '4,', '', "'", 's', 't', 'd', "'", ':', '', '119', '.', '60', '4', '35', '80', '133', '25', '96', ',', '', "'", 'media', 'n', "'", ':', '', '-5', '13', '.', '65', '39', '21', '203', '88', '46', ',', '', "'", 'min', "'", ':', '', '-7', '39', '.', '2', '88', '365', '60', '85', '27', '4,', '', "'", 'max', "'", ':', '', '-2', '97', '.', '47', '31', '79', '21', '40', '42', '26', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.00', '136', '404', '210', '176', '74', '12', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-1', '.', '105', '63', '84', '92', '866', '74', '78', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-60', '4.4', '62', '92', '430', '21', '98', '1,', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-40', '5.', '45', '333', '235', '62', '46', '56', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'author', 'ities', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '3', 'aff', 'b', 'c', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-', '69', '9.5', '18', '70', '28', '70', '35', '71', ',', '', "'", 's', 't', 'd', "'", ':', '', '74', '.', '80', '23', '08', '15', '77', '168', ',', '', "'", 'media', 'n', "'", ':', '', '-', '70', '1.3', '840', '95', '26', '24', '48', '8,', '', "'", 'min', "'", ':', '', '-8', '49', '.', '640' ...
# ["This scatterplot shows the distribution of values over time for 'Martha', with a mean of -510.183 and a standard deviation of 0.645. While there is some drift, the values periodically return to their original mean. There are three distinct groups, and one group (the green 'authorities' group) stands out with an amplitude difference of approximately 11% compared to the other groups."]
# '"This scatterplot depicts the distribution of values over time for \'Martha\', with a mean of -512.804 and a standard deviation of 3.677. The data exhibits periodic drift, but returns to its original value periodically. There are three distinct groups, and one of them, the green \'authorities\' group, has an amplitude difference of approximately 18% compared to the other groups."'

# %%
idx=7

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", '<unk>', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", 'call', 's', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 're', 'l', "'", ',', '', "'", 'color', "'", ':', '', "'", '#',
',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.0', '60', '17', '3', '77', '106', '17', '123', '1,', '', "'", 'kur', 'to', 's', 'is', "'", ':', '',  ...
# ['This scatterplot illustrates the relationship between \'nav>\' and \']",\', with a mean of 1219.429 and a standard deviation of 249.427 for \'nav>\', and a mean of -1606.063 and a standard deviation of 348.429 for \']",\'. There are a total of 9 groups, and the correlation coefficient is -0.01, indicating no linear relationship between the two datasets.']
# 'This scatterplot illustrates the relationship between \'<nav>\' and \']",\' with a mean of 1204.94 and a standard deviation of 255.629 for \'<nav>\', and a mean of -1633.732 and a standard deviation of 282.567 for \']",\'. There are a total of 9 groups, and the correlation coefficient is 0.84, indicating a strong linear relationship between the two data sets.'

# %%
idx=10

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'certain', 't', 'y', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", '<unk>', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'NP', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'a', '400', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-6', '22', '.', '78', '199', '08', '13', '76', '57', ',', '', "'", 's', 't', 'd', "'", ':', '', '9.5', '36', '98', '86', '88', '640', '34', '4,', '', "'", 'media', 'n', "'", ':', '', '-', '62', '2.6', '86', '149', '25', '16', '37', '3,', '', "'", 'min', "'", ':', '', '-', '64', '3.5', '75', '95', '39', '29', '40', '8,', '', "'", 'max', "'", ':', '', '-5', '95', '.', '167', '93', '81', '73', '160', '3,', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '111', '222', '28', '71', '225', '29', '42', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.1', '59', '81', '64', '72', '77', '450', '95', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-6', '28', '.', '67', '73', '38', '122', '13', '28', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-6', '17', '.', '50', '74', '177', '450', '404', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'head', 'er', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0', 'f', 'f', '8', 'e', '8', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-6', '49', '.', '96', '6', '18', '90', '46', '90', '16', ',', '', "'", 's', 't', 'd', "'", ':', '9.', '67', '73', '24', '79', '58', '44', '39', '2,', '', "'", 'media', 'n', "'", ':', '', '-6', '49', '.', '91', '205', '21', '75', '32', '48', ',', '', "'", 'min', "'", ':', '', '-6', '71', '.', '59', '35', '177', '35', '87', '12', ',', '', "'", 'max', "'", ':', '', '-', '62', '4.0', '56', '97', '39', '67', '03', '81', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '25', '206', '147', '216', '37', '216', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.1', '58', '08', '46', '88', '94', '30', '760', '3,', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '65', '6.7', '79', '62', '79', '22', '57', '69', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-6', '43', '.', '93', '56', '17', '124', '63', '46', '<unk>', '],', '', "'", 'y', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'NP', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', 'a', '400', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-6', '28', '.', '84', '999', '46', '95', '36', '27', ',', '', "'", 's', 't', 'd', "'", ':', '9.', '65', '51', '46', '75', '96', '207', '1,', '', "'", 'media', 'n', "'", ':', '', '-6', '28', '.', '85', '73', '67', '63', '15', '877', ',', '', "'", 'min', "'", ':', '', '-', '65', '2.8', '270', '84', '22', '127', '01', ',', '', "'", 'max', "'", ':', '', '-60', '5.', '95', '92', '48', '19', '119', '44', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '15', '65', '148', '52', '88', '06', '13', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.1', '31', '36', '28', '67', '72', '25', '45', '57', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '-', '63', '5.7', '90', '94', '28', '54', '78', '53', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '-', '62', '3.2', '42', '84', '27', '98', '32', '65', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'head', 'er', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0', 'f', 'f', '8', 'e', '8', "'", ',', '', "'", 'me', 'an', "'", ':', '', '
'<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", '?"', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'e', '8', 'f', 'f', '0', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '', '-19', '1.1', '76', '19', '40', '86', '79', '97', ',', '', "'", 's', 't', 'd', "'", ':', '', '1.8', '107', '99', '32', '197', '57', '177', ',', '', "'", 'media', 'n', "'", ':', '', '-19', '1.3', '19', '183', '44', '147', '94', '2,', '', "'", 'min', "'", ':', '', '-19', '4.8', '78', '89', '48', '2', '450', '63', '2,', '', "'", 'max', "'", ':', '', '-', '186', '.', '87', '57', '67', '330', '770', '5,', '', "'", 'ske', 'w', 'ness', "'", ':', '', '0.3', '64', '1000', '70 ...
# ["This scatterplot illustrates the relationship between 'Welfare' and 'Cap', with a mean of -191.192 and a standard deviation of 1.707 for 'Welfare', and a mean of 944.191 and a standard deviation of 179.486 for 'Cap'. There are a total of 7 groups, and the correlation coefficient is 0.014, indicating no linear relationship between the two datasets."]
# "This scatterplot illustrates the relationship between 'Welfare' and 'Cap', with a mean of -191.209 and a standard deviation of 2.034 for the 'Welfare' data, and a mean of 945.108 and a standard deviation of 185.908 for the 'Cap' data. The correlation coefficient is 0.14, indicating little to no linearity between the two datasets. There are a total of 7 groups represented in this graph."

# %%
idx=13

import torch
outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
print(decoded_preds)
decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(decoded_preds)
tokenized_dataset["test"][idx]['text']
# Out:
# ['', '<unk>', "'", 'x', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', "'", 'Super', "'", '"', ',', '', "'", 'y', '-', 'axi', 's', '-', 'l', 'abel', "'", ':', '"', '', "'", '<unk>', "'", '",', '', "'", 'x', '-', 'axi', 's', '-', 'feature', 's', "'", ':', '[', '<unk>', "'", 'group', "'", ':', '', "'", 'Ch', 'rome', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '00', 'c', '3', 'f', 'f', "'", ',', '', "'", 'me', 'an', "'", ':', '13', '18', '.', '72', '47', '99', '32', '66', '97', '2,', '', "'", 's', 't', 'd', "'", ':', '', '2.3', '48', '800', '21', '59', '54', '38', '1,', '', "'", 'media', 'n', "'", ':', '13', '18', '.', '93', '76', '63', '138', '23', '1,', '', "'", 'min', "'", ':', '', '131', '3.9', '80', '34', '660', '500', '07', ',', '', "'", 'max', "'", ':', '', '132', '3.9', '22', '85', '68', '49', '184', '2,', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.2', '54', '99', '33', '32', '18', '264', '39', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.6', '183', '02', '62', '63', '55', '45', '23', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '13', '16', '.99', '34', '15', '64', '63', '39', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '132', '0.4', '24', '850', '94', '29', '49', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'W', 'if', 'e', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'b', 'd', '0000', "'", ',', '', "'", 'me', 'an', "'", ':', '13', '18', '.', '82', '50', '610', '45', '83', '42', ',', '', "'", 's', 't', 'd', "'", ':', '2.', '73', '93', '99', '29', '70', '65', '60', '74', ',', '', "'", 'media', 'n', "'", ':', '', '131', '8.5', '03', '130', '70', '98', '53', '4,', '', "'", 'min', "'", ':', '', '131', '2.7', '530', '88', '68', '90', '16', ',', '', "'", 'max', "'", ':', '', '132', '4.0', '303', '58', '108', '22', '76', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.0', '83', '22', '86', '49', '45', '100', '79', '4,', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.7', '24', '41', '98', '57', '2', '78', '57', '45', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '13', '16', '.', '8', '58', '76', '100', '183', '42', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '', '132', '0.9', '69', '19', '190', '42', '79', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", 'са', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', '0000', 'f', 'a', "'", ',', '', "'", 'me', 'an', "'", ':', '13', '17', '.', '8', '70', '98', '27', '73', '86', '99', ',', '', "'", 's', 't', 'd', "'", ':', '2.', '66', '68', '47', '430', '760', '126', '4,', '', "'", 'media', 'n', "'", ':', '13', '18', '.', '09', '925', '43', '80', '23', '13', ',', '', "'", 'min', "'", ':', '13', '12.', '36', '95', '29', '37', '12', '117', ',', '', "'", 'max', "'", ':', '13', '22', '.', '76', '53', '79', '56', '145', '28', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '', '-', '0.2', '07', '43', '08', '55', '56', '76', '13', '18', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '', '-', '0.8', '150', '33', '19', '7000', '79', '05', ',', '', "'", 'first', '-', 'quart', 'ile', "'", ':', '', '131', '5.7', '63', '62', '99', '75', '54', '25', ',', '', "'", 'third', '-', 'quart', 'ile', "'", ':', '13', '19', '.', '94', '310', '76', '35', '17', '05', '<unk>', ',', '', '<unk>', "'", 'group', "'", ':', '', "'", '<unk>', "'", ',', '', "'", 'color', "'", ':', '', "'", '#', 'f', 'f', '7', '200', "'", ',', '', "'", 'me', 'an', "'", ':', '', '131', '8.5', '49', '93', '85', '83', '97', '12', ',', '', "'", 's', 't', 'd', "'", ':', '2.5', '83', '40', '31', '978', '20', '96', '5,', '', "'", 'media', 'n', "'", ':', '13', '18', '.', '37', '3', '108', '24', '79', '58', ',', '', "'", 'min', "'", ':', '13', '12.', '45', '91', '94', '66', '76', '24', ',', '', "'", 'max', "'", ':', '13', '25', '.', '380', '90', '71', '2', '233', '63', ',', '', "'", 'ske', 'w', 'ness', "'", ':', '0.', '24', '42', '28', '53', '88', '07', '95', '25', ',', '', "'", 'kur', 'to', 's', 'is', "'", ':', '0.', '25', '68', ...
# ["This scatterplot illustrates the relationship between 'Super' and '', with a mean of 1318.429 and a standard deviation of 2.845 for 'Super', and a mean of 1610.95 and a standard deviation of 407.486 for ''. There are a total of 8 groups, and the correlation coefficient is -0.014, indicating no linear relationship between the two datasets."]
# '"This scatterplot represents the relationship between \'Super\' and \'\\\'. The mean of \'Super\' is 1318.593, with a standard deviation of 2.62, while the mean of \'\\\' is 1645.551 with a standard deviation of 366.757. There are a total of 8 groups, and the correlation coefficient between the two data sets is 0.023, indicating no linear relationship."'

# %%
# %matplotlib inline

# from PIL import Image
import matplotlib.pyplot as plt
import torch
from IPython.display import display
from IPython.display import Image, display
for idx in range(len(tokenized_dataset["test"])):
  outputs = model.generate(input_ids=torch.tensor(tokenized_dataset["test"][idx]['input_ids']).unsqueeze(0).to('cuda'), max_new_tokens=1024)
  decoded_preds = tokenizer.batch_decode(tokenized_dataset["test"][idx]['input_ids'], skip_special_tokens=True)
  ad=tokenized_dataset["test"][idx]['origin_text'].split('/')
  ad[-1]=ad[-1].split('.')[0]+'.png'
  ad[-3]='image'
  imageadd=os.path.join(*ad)
  # img = Image.open(imageadd).convert("RGB")
  # img.show()
  display(Image(filename=imageadd))
  decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
  print('pred : ',decoded_preds[0])
  print('ans : ', tokenized_dataset["test"][idx]['text'])
# Out:
# Output hidden; open in https://colab.research.google.com to view.
