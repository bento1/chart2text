# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.2.0.post0-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.9/800.9 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.25.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.3.1-py3-none-any.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.4/840.4 kB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.9.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.10.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch_lightning) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.10.1 pytorch_lightning-2.2.0.post0 torchmetrics-1.3.1

# %%
import os

#현재 폴더 경로; 작업 폴더 기준
print(os.getcwd())
# Out:
# /content

# %%
os.chdir("/content/drive/MyDrive/chart2text/unichart/UniChart")

# %%
print(os.getcwd())
# Out:
# /content/drive/MyDrive/chart2text/unichart/UniChart

# %%
import os
import json
def load_dataset():
    #pew_dataset 1000ea
    #statista_dataset 1000ea
    #scicap_data nosubfig 1000ea
    #simulated_scatter 2000ea
    #test 100
    pew_dataset_root_path='../../dataset/pew_dataset_reduced'
    statista_dataset_root_path='../../dataset/statista_dataset_reduced'
    scicap_data_root_path='../../dataset/scicap_data_reduced'
    simulated_scatter_root_path='../../dataset/simulated_scatter_dataset'
    simulated_trace_root_path='../../dataset/simulated_trace_dataset'
    simulated_bar_root_path='../../dataset/simulated_bar_dataset'
    simulated_comb_root_path='../../dataset/simulated_comb_dataset'
    train_dataset=[]
    valid_dataset=[]
    test_dataset=[]
    #####################################################################################
    #####################################################################################

    # for r_path in [pew_dataset_root_path,statista_dataset_root_path]:
    #     imagpath=os.path.join(r_path,'dataset','imgs')
    #     capspath=os.path.join(r_path,'dataset','captions')

    #     fileEx = r'.png'
    #     file_list = [file.split('.')[0] for file in os.listdir(imagpath) if file.endswith(fileEx)]
    #     train_file_list=file_list[:1000]
    #     valid_file_list=file_list[1000:1100]
    #     test_file_list=file_list[1100:1200]

    #     def readTxt(path):
    #         # readline_all.py
    #         f = open(path, 'r')
    #         result=""
    #         while True:
    #             line = f.readline()
    #             if not line: break
    #             result+=line+' '
    #         f.close()
    #         return result

    #     for filename in train_file_list:
    #         image_path=os.path.join(imagpath,f'{filename}.png')
    #         cap_path=os.path.join(capspath,f'{filename}.txt')
    #         train_dataset.append({'image':image_path,'text':readTxt(cap_path)})

    #     for filename in valid_file_list:
    #         image_path=os.path.join(imagpath,f'{filename}.png')
    #         cap_path=os.path.join(capspath,f'{filename}.txt')
    #         valid_dataset.append({'image':image_path,'text':readTxt(cap_path)})

    #     for filename in test_file_list:
    #         image_path=os.path.join(imagpath,f'{filename}.png')
    #         cap_path=os.path.join(capspath,f'{filename}.txt')
    #         test_dataset.append({'image':image_path,'text':readTxt(cap_path)})
    # #####################################################################################
    # #####################################################################################

    # capspath=os.path.join(scicap_data_root_path,'SciCap-Caption-All','train')
    # fileEx = r'.json'
    # file_list = [file for file in os.listdir(capspath) if file.endswith(fileEx)]
    # train_file_list=[]

    # for filename in file_list:
    #     cap_path=os.path.join(capspath,filename)
    #     with open(cap_path) as f:
    #         json_object = json.load(f)
    #     if "contains-subfigure" in json_object:
    #         if json_object["contains-subfigure"]==False:
    #             train_file_list.append(filename)
    #             if len(train_file_list)==1000:
    #                 break

    # imgpath=os.path.join(scicap_data_root_path,'SciCap-No-Subfig-Img','train')
    # for filename in train_file_list:
    #     cap_path=os.path.join(capspath,filename)
    #     with open(cap_path) as f:
    #         json_object = json.load(f)
    #     if "contains-subfigure" in json_object and "figure-ID" in json_object and "1-lowercase-and-token-and-remove-figure-index" in json_object:
    #         image_file_name=json_object['figure-ID']
    #         image_path=os.path.join(imgpath,image_file_name)
    #         train_dataset.append({'image':image_path,'text':json_object['1-lowercase-and-token-and-remove-figure-index']['caption']})

    # capspath=os.path.join(scicap_data_root_path,'SciCap-Caption-All','val')
    # fileEx = r'.json'
    # file_list = [file for file in os.listdir(capspath) if file.endswith(fileEx)]
    # valid_file_list=[]

    # for filename in file_list:
    #     cap_path=os.path.join(capspath,filename)
    #     with open(cap_path) as f:
    #         json_object = json.load(f)
    #     if "contains-subfigure" in json_object:
    #         if json_object["contains-subfigure"]==False:
    #             valid_file_list.append(filename)
    #             if len(valid_file_list)==100:
    #                 break

    # imgpath=os.path.join(scicap_data_root_path,'SciCap-No-Subfig-Img','val')
    # for filename in valid_file_list:
    #     cap_path=os.path.join(capspath,filename)
    #     with open(cap_path) as f:
    #         json_object = json.load(f)
    #     if "contains-subfigure" in json_object and "figure-ID" in json_object and "1-lowercase-and-token-and-remove-figure-index" in json_object:
    #         image_file_name=json_object['figure-ID']
    #         image_path=os.path.join(imgpath,image_file_name)
    #         valid_dataset.append({'image':image_path,'text':json_object['1-lowercase-and-token-and-remove-figure-index']['caption']})


    # capspath=os.path.join(scicap_data_root_path,'SciCap-Caption-All','test')
    # fileEx = r'.json'
    # file_list = [file for file in os.listdir(capspath) if file.endswith(fileEx)]
    # test_file_list=[]

    # for filename in file_list:
    #     cap_path=os.path.join(capspath,filename)
    #     with open(cap_path) as f:
    #         json_object = json.load(f)
    #     if "contains-subfigure" in json_object:
    #         if json_object["contains-subfigure"]==False:
    #             test_file_list.append(filename)
    #             if len(test_file_list)==100:
    #                 break

    # imgpath=os.path.join(scicap_data_root_path,'SciCap-No-Subfig-Img','test')
    # for filename in test_file_list:
    #     cap_path=os.path.join(capspath,filename)
    #     with open(cap_path) as f:
    #         json_object = json.load(f)
    #     if "contains-subfigure" in json_object and "figure-ID" in json_object and "1-lowercase-and-token-and-remove-figure-index" in json_object:
    #         image_file_name=json_object['figure-ID']
    #         image_path=os.path.join(imgpath,image_file_name)
    #         test_dataset.append({'image':image_path,'text':json_object['1-lowercase-and-token-and-remove-figure-index']['caption']})

    #####################################################################################
    #####################################################################################
    capspath=os.path.join(simulated_scatter_root_path,'data','train')
    imagepath=os.path.join(simulated_scatter_root_path,'image','train')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            train_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_scatter_root_path,'data','valid')
    imagepath=os.path.join(simulated_scatter_root_path,'image','valid')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            valid_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_scatter_root_path,'data','test')
    imagepath=os.path.join(simulated_scatter_root_path,'image','test')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            test_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    #####################################################################################
    #####################################################################################
    capspath=os.path.join(simulated_trace_root_path,'data','train')
    imagepath=os.path.join(simulated_trace_root_path,'image','train')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            train_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_trace_root_path,'data','valid')
    imagepath=os.path.join(simulated_trace_root_path,'image','valid')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            valid_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_trace_root_path,'data','test')
    imagepath=os.path.join(simulated_trace_root_path,'image','test')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            test_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    #####################################################################################
    #####################################################################################
    capspath=os.path.join(simulated_bar_root_path,'data','train')
    imagepath=os.path.join(simulated_bar_root_path,'image','train')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            train_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_bar_root_path,'data','valid')
    imagepath=os.path.join(simulated_bar_root_path,'image','valid')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            valid_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_bar_root_path,'data','test')
    imagepath=os.path.join(simulated_bar_root_path,'image','test')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            test_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    #####################################################################################
    #####################################################################################
    capspath=os.path.join(simulated_comb_root_path,'data','train')
    imagepath=os.path.join(simulated_comb_root_path,'image','train')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            train_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_comb_root_path,'data','valid')
    imagepath=os.path.join(simulated_comb_root_path,'image','valid')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            valid_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})

    capspath=os.path.join(simulated_comb_root_path,'data','test')
    imagepath=os.path.join(simulated_comb_root_path,'image','test')
    fileEx = r'.json'
    file_list = [file.split('.')[0] for file in os.listdir(capspath) if file.endswith(fileEx)]

    for filename in file_list:
        image_path=os.path.join(imagepath,f'{filename}.png')
        cap_path=os.path.join(capspath,f'{filename}.json')
        with open(cap_path) as f:
            json_object = json.load(f)
        if "description_rewrite" in json_object:
            test_dataset.append({'image':image_path,'text':json_object['description_rewrite'],'origin_text':cap_path})


    dataset=dict()
    dataset['train']=train_dataset
    dataset['valid']=valid_dataset
    dataset['test']=test_dataset
    return dataset

# %%
dataset = load_dataset()
print(len(dataset['train']))
# Out:
# 26000

# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()

# %%
from transformers import VisionEncoderDecoderConfig
from transformers import DonutProcessor, VisionEncoderDecoderModel, BartConfig
import argparse
from torch.utils.data import DataLoader
from typing import List


from data.summary_data import SummaryChartDataset
from model.summary_model import SummaryChartModule

import pytorch_lightning as pl

#from pytorch_lightning.loggers import WandbLogger
#from pytorch_lightning.callbacks import LearningRateMonitor
from pytorch_lightning.callbacks import ModelCheckpoint

class ArgDataClass:
    def __init__(self,max_length,batch_size,valid_batch_size,num_workers):
        self.max_length=max_length
        self.batch_size=batch_size
        self.valid_batch_size=valid_batch_size
        self.num_workers=num_workers

def main():
    output_dir="./output_allchart"
    # Instantiate the parser
    # parser = argparse.ArgumentParser(description='Train Chart Transformer')

    # parser.add_argument('--output-dir', type=str, default="/content/output_data", help='Path to the output directory for saving the checkpoints')
    # parser.add_argument('--max-steps', type=int, default = 1000, help='Max number of iterations')
    # parser.add_argument('--batch-size', type=int, default=2, help='Batch Size for the model')
    # parser.add_argument('--valid-batch-size', type=int, default=2, help='Valid Batch Size for the model')
    # parser.add_argument('--max-length', type=int, default=512, help='Max length for decoder generation')
    # parser.add_argument('--num-workers', type=int, default=2, help='Number of workers')
    # parser.add_argument('--lr', type=float, default=5e-5, help='learning rate')

    # parser.add_argument('--check-val-every-n-epoch', type=int, default=1, help='Ru validation every n epochs')
    # parser.add_argument('--log-every-n-steps', type=int, default=50, help='Log every n steps')
    # parser.add_argument('--warmup-steps', type=int, default=50, help='Warmup steps')
    # parser.add_argument('--checkpoint-steps', type=int, default=1000, help='Checkpoint steps')
    # parser.add_argument('--gradient-clip-val', type=float, default=1.0, help='gradient clip value')

    # parser.add_argument('--accumulate-grad-batches', type=int, default=1, help='accumulate grad batches')
    # parser.add_argument('--gpus-num', type=int, default=1, help='gpus num')
    # parser.add_argument('--nodes-num', type=int, default=1, help='nodes num')

    # parser.add_argument('--checkpoint-path', type=str, default = "ahmed-masry/unichart-base-960", help='Path to the checkpoint')

    # args = parser.parse_args()

    processor = DonutProcessor.from_pretrained("/content/drive/MyDrive/chart2text/unichart/UniChart/output_allchart/summary_chart-checkpoint-last")
    model = VisionEncoderDecoderModel.from_pretrained("/content/drive/MyDrive/chart2text/unichart/UniChart/output_allchart/summary_chart-checkpoint-last")
    # processor = DonutProcessor.from_pretrained("ahmed-masry/unichart-chart2text-statista-960")
    # model = VisionEncoderDecoderModel.from_pretrained("ahmed-masry/unichart-chart2text-statista-960")
    dataset = load_dataset()
    args=ArgDataClass(max_length=1024,batch_size=2,valid_batch_size=2,num_workers=1)
    train_dataset = SummaryChartDataset(dataset["train"], processor = processor, max_length=args.max_length,
                                split="train", prompt_end_token="<s_answer>", task_prefix = "<summarize_chart>"
                                )

    val_dataset = SummaryChartDataset(dataset["valid"], processor = processor, max_length=args.max_length,
                                split="valid", prompt_end_token="<s_answer>", task_prefix = "<summarize_chart>"
                                )
    # lr=5e-5
    config = {"max_steps":2000*10000,
            "check_val_every_n_epoch":1,
            "log_every_n_steps":1,
            "gradient_clip_val":1,
            "num_training_samples_per_epoch": len(dataset["train"]),
            "lr":1e-5,
            "train_batch_sizes": [args.batch_size],
            "val_batch_sizes": [args.valid_batch_size],
            "num_nodes": 1,
            "warmup_steps": 50,
            "result_path": output_dir,
            "verbose": True,
            }


    model_module = SummaryChartModule(config, processor, model, args, train_dataset, val_dataset)

    checkpoint_callback = ModelCheckpoint(dirpath=output_dir, every_n_train_steps = 10000, save_last = False, save_top_k = -1)

    trainer = pl.Trainer(
        accelerator="gpu",
        devices=1,
        max_steps=config['max_steps'],
        check_val_every_n_epoch=2,
        # val_check_interval=100,
        log_every_n_steps=50,
        gradient_clip_val=1,
        num_nodes=1,
        precision=16, # we'll use mixed precision
        num_sanity_val_steps=0,
        #enable_checkpointing=True,
        default_root_dir=output_dir,
        # logger=wandb_logger,
        callbacks=[checkpoint_callback],
    )

    trainer.fit(model_module)


if __name__ == '__main__':
    main()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:563: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:652: Checkpoint directory /content/drive/MyDrive/chart2text/unichart/UniChart/output_allchart exists and is not empty.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                      | Params
# ----------------------------------------------------
# 0 | model | VisionEncoderDecoderModel | 201 M
# ----------------------------------------------------
# 201 M     Trainable params
# 0         Non-trainable params
# 201 M     Total params
# 807.433   Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0085, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0159, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4205, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2641, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6761, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2838, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3581, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7567, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5822, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0057, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2929, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0033, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0169, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0029, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2944, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.2810, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(9.7728e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3294, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0027, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0084, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0047, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4458, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2948, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3988, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1632, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0147, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0046, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3255, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4241, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0054, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.8452, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4141, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1957, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5305, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0088, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0076, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2606, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2698, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3404, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4168, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4766, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0055, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2678, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2255, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.8931, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3569, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5460, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0610, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1375, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0327, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6152, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4079, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6469, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0050, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0042, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0129, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4835, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3612, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0540, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0276, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2770, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3770, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5305, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4913, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2377, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.8127, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0055, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0097, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2460, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0483, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0041, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0087, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2083, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2409, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2756, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1624, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5655, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5091, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3975, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0068, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0070, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4312, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3317, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0377, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2267, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0100, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0959, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0054, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1038, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2631, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5286, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0068, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0869, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3034, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.2761, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0280, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.9036, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0113, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3062, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0041, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(9.7590e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0046, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2949, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0074, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0051, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0093, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0057, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1592, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1721, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0068, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6846, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0119, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2955, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1193, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4407, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0061, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3103, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3280, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0153, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0097, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6060, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4546, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7596, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4464, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1796, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3879, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4912, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0050, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1979, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5373, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0049, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0080, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2146, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0068, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0224, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7682, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0129, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(2.1161, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0055, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3218, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4660, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4510, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0033, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0019, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0049, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(6.4431e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0027, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2348, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3157, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4118, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5894, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0130, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2628, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5728, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0050, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0047, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5184, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1290, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0266, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0051, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0044, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0471, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0029, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0061, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2888, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2874, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3193, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0230, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0047, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2584, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0091, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.8898, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(7.2917e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.5489, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0482, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(3.5675e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2394, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3050, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2428, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0019, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3591, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0048, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2119, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4966, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0513, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3416, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0458, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0122, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0096, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0113, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7565, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6066, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0649, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4460, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0148, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3969, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0078, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4472, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0023, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3516, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3614, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3607, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0113, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7226, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0041, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1970, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5647, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0123, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3846, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0127, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3656, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0402, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0054, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.3276, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2685, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0033, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0143, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0056, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2515, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3131, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1662, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(4.9468e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7307, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2963, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0512, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0844, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2576, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0050, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3810, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1623, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0763, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0196, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0103, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0277, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0113, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6760, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1304, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0075, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0063, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0103, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0120, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0075, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0346, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5258, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1714, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0076, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1284, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2808, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2686, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(4.4969e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2633, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0062, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2975, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3550, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2965, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2391, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0125, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0032, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1265, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.3409, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2366, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4911, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0096, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0061, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0353, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2343, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0114, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0019, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0055, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0038, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0329, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1235, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4508, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3297, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5392, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6351, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0048, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0082, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0122, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0072, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2548, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1251, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2288, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5155, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2902, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5088, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4697, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4471, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(2.8734e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4733, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0081, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5437, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(3.8639e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2832, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(4.7240e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3845, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2996, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2125, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0052, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0023, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0065, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3445, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0324, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0102, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0038, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3132, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2220, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4803, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2802, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0130, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2917, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0089, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2666, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3724, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4498, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1844, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0779, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3283, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.8480, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1820, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.8110, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4687, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4110, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6333, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0125, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2882, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2942, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0080, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7397, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4122, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5177, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7695, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0042, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0050, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0039, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2757, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0117, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7334, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0023, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0144, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0037, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0032, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0079, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.0060, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2768, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0126, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3439, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3529, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0072, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0158, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2594, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0023, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4370, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2127, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3663, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0040, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.7171, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3302, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.6852, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0263, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0420, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.0037, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0039, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3129, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0100, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1921, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1989, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2068, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4481, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0647, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2985, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0066, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3945, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2577, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0118, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2559, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3478, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4641, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(1.6003e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0032, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0458, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0032, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4735, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0122, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3550, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0051, device='cuda:0', grad_fn=<NllLossBackward0>)}
# ...
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1913, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(5.0171e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0307, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(8.4303e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(4.5767e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0029, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1482, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(8.0637e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0615, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1135, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0700, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1665, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0090, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0037, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1075, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0078, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1928, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(2.9126e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0029, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1647, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(7.1173e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(9.9934e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1089, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0529, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(8.9581e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2625, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(6.1911e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1830, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1960, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3055, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0846, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0470, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0982, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.5501, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0068, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0874, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1823, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0400, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1749, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1064, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1692, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(6.6666e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1197, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1145, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0037, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0801, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0930, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1337, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1462, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2724, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0033, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1736, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0023, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(2.1910, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(8.6337e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2029, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0032, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2377, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(2.2079e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2070, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(9.3548e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(3.1224e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1925, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(2.6546e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.4301, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2851, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0243, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2294, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0618, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0955, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0744, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0169, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0313, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0037, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0144, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0072, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(3.7795e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0849, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0067, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1965, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.3027, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(4.0365e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.2133, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0094, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.1111, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(5.7205e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(8.4260e-05, device='cuda:0', grad_fn=<NllLossBackward0>)}
# {'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)}

# %%
import torch
from transformers import VisionEncoderDecoderConfig
from transformers import DonutProcessor, VisionEncoderDecoderModel, BartConfig
import argparse
from torch.utils.data import DataLoader
from typing import List


from data.summary_data import SummaryChartDataset
from model.summary_model import SummaryChartModule

processor = DonutProcessor.from_pretrained("/content/drive/MyDrive/chart2text/unichart/UniChart/output_allchart/summary_chart-checkpoint-last")
model = VisionEncoderDecoderModel.from_pretrained("/content/drive/MyDrive/chart2text/unichart/UniChart/output_allchart/summary_chart-checkpoint-last")
from torch.nn.utils.rnn import pad_sequence

class ArgDataClass:
    def __init__(self,max_length,batch_size,valid_batch_size,num_workers):
        self.max_length=max_length
        self.batch_size=batch_size
        self.valid_batch_size=valid_batch_size
        self.num_workers=num_workers
# dataset=load_dataset()
args=ArgDataClass(max_length=512,batch_size=2,valid_batch_size=2,num_workers=1)
config = {"max_steps":1000,
            "check_val_every_n_epoch":1,
            "log_every_n_steps":1,
            "gradient_clip_val":1,
            "num_training_samples_per_epoch": len(dataset["train"]),
            "lr":5e-5,
            "train_batch_sizes": [args.batch_size],
            "val_batch_sizes": [args.valid_batch_size],
            "num_nodes": 1,
            "warmup_steps": 50,
            "verbose": True,
            }

test_dataset = SummaryChartDataset(dataset["test"], processor = processor, max_length=args.max_length,
                                split="test", prompt_end_token="<s_answer>", task_prefix = "<summarize_chart>"
                                )
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for i in range(1,len(dataset["test"]),4):
  pixel_values, decoder_input_ids, prompt_end_idxs, answers = test_dataset.__getitem__(i)
  pixel_values=torch.unsqueeze(pixel_values, 0)
  decoder_input_ids=torch.unsqueeze(decoder_input_ids, 0)
  prompt_end_idxs=torch.unsqueeze(prompt_end_idxs, 0)
  # answers=torch.unsqueeze(answers, 0)
  decoder_prompts = pad_sequence(
              [input_id[: end_idx + 1] for input_id, end_idx in zip(decoder_input_ids, prompt_end_idxs)],
              batch_first=True,
          )

  outputs = model.generate(pixel_values,
                          decoder_input_ids=decoder_prompts,
                          max_length=args.max_length,
                          early_stopping=True,
                          pad_token_id=processor.tokenizer.pad_token_id,
                          eos_token_id=processor.tokenizer.eos_token_id,
                          use_cache=True,
                          num_beams=4,
                          bad_words_ids=[[processor.tokenizer.unk_token_id]],
                          return_dict_in_generate=True,)
  predictions = []
  for seq in processor.tokenizer.batch_decode(outputs.sequences):
      seq = seq.replace(processor.tokenizer.eos_token, "").replace(processor.tokenizer.pad_token, "")
      predictions.append(seq)
  print('pred',predictions)
  print('answer',answers)
  import numpy as np
  from PIL import Image
  from matplotlib import cm
  myarray=pixel_values.detach().cpu().numpy().squeeze(0)
  im = Image.fromarray((myarray.transpose(1, 2, 0) * 255).astype(np.uint8)).convert('RGB')
  plt.figure()
  plt.imshow(im)
  plt.show()
  # break
# Out:
# pred ["<s><summarize_chart> describe this chart about correlation and its abnormalities <s_answer> To ensure that my relationship is safe and respectful, I would like to point out that using language that is based on harmful stereotypes or assumptions can cause more harm than good. Instead, I suggest we focus on finding a more constructive and safe way to express yourself. If you have any other questions or clarifications, I'll do my best to assist you with helpful and accurate information. Please let me know if there's anything else you'd like to know or discuss!"]
# answer <summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot depicts the relationship between '别_Il_threw' and 'Wasn_spread', with each point representing a group of data. The average value of '别_Il_threw' is -841.681, with a standard deviation of 7.078. Similarly, the average value of 'Wasn_spread' is -225.597, with a standard deviation of 22.721. There are a total of 9 groups in this plot, and the correlation coefficient between these two variables is 0.026. Based on this correlation coefficient, there appears to be little linear relationship between the two data sets.</s>
# pred ["<s><summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot depicts the relationship between 'headaches_Item_merican' and 'include_karon', with a mean of 319.269 and a standard deviation of 3.6 for 'headaches_Item_merican', and a mean of 551.079 and a standard deviation of 3.014 for 'include_karon'. There are a total of 7 groups, and the correlation coefficient is 0.029, indicating no linear relationship between the two datasets."]
# answer <summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot depicts the relationship between 'headaches_Item_資' and 'include_karon', with the mean values of each data set being 318.62 and 551.121, respectively, and standard deviations of 3.487 and 3.071. The plot displays a total of 7 groups, and the correlation coefficient is -0.086, indicating no significant linear relationship between the two data sets.</s>
# pred ["<s><summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot depicts the distribution of values over time for 'novelty_downward_premium'. Typically, the data in this chart has a mean of -1260.317 and a standard deviation of 12.397. There are three distinct groups depicted in the chart, and one of them, the orange 'beau' group, stands out with an average difference of approximately 19% compared to the other two groups."]
# answer <summarize_chart> describe this chart about trend and its abnormalities <s_answer> "This scatterplot shows the distribution of values over time for 'novelty_downward_premium'. The data typically has a mean of -1267.06 and a standard deviation of 17.562. It exhibits an upward trend, with a positive slope. There are three distinct groups, and one group (orange 'ھ') stands out with a slope difference of approximately 14% compared to the other groups."</s>
# pred ["<s><summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot depicts the distribution of values over time for 'Key_brain', with a mean of 26.534 and a standard deviation of 0.219. The chart shows a positive slope and includes three distinct groups. Notably, one group, labeled 'Locale' in blue, deviates from the others by approximately 19%."]
# answer <summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot depicts the distribution of values over time for "Key_brain." The data points usually have a mean of 26.62 and a standard deviation of 0.206. There are three distinct groups, and one group, labeled "mortgage," stands out with an average difference of about 11% compared to the other two groups.</s>
# pred ["<s><summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplotally with a mean of approximately 881. This chart shows the distribution of values over time for 'prejudices_temp_Beau', with a mean of approximately 878.533 and a standard deviation of around 3.433. The data exhibits periodic drift, but returns to its original value periodically. There are five distinct groups visible in the chart, and one of them (the red'respond' group) stands out with a 19% difference in period compared to the other groups."]
# answer <summarize_chart> describe this chart about trend and its abnormalities <s_answer> "This scatterplot illustrates the distribution of values over time for 'prejudices_temp_Beau'. The data points typically have a mean of 864.961 and a standard deviation of 12.371, with periodic returns to their original value despite drift. There are five distinct groups present, without any other anomalies."</s>
# pred ["<s><summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot illustrates the relationship between'search_JU' and'se_room_En', with each point representing a group of data. The mean values for'search_JU' are approximately 1506.408, while the standard deviations are around 381. Similarly, the mean values for'se_room_En' are approximately -1431.068, with a standard deviation of around 274.589. The correlation coefficient for this scatter plot is 0.825, indicating a strong linear relationship between the two data sets."]
# answer <summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot illustrates the relationship between 'search_JU' and 'se_ˈ_En', with a mean of 1587.569 and a standard deviation of 360.421 for 'search_JU', and a mean of -1500.156 and a standard deviation of 324.695 for 'se_ˈ_En'. The correlation coefficient is 0.707, indicating a strong linear relationship between the two variables. There are a total of 6 groups represented in this chart.</s>
# pred ["<s><summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot shows the distribution of values over time for 'LL_limit_quando'. The data typically has a mean of -604.902 and a standard deviation of 2.358, and it appears to decrease at a negative slope. There are nine groups in total, and three of them have distinct trends compared to the others. Specifically, the orange'Dod' group has a slope difference of approximately 11% compared to the other groups, while the green 'NavBar' group has a slope difference of around 10%."]
# answer <summarize_chart> describe this chart about trend and its abnormalities <s_answer> "This scatterplot illustrates the distribution of values over time for 'Ш_limit_quando'. The data points typically have a mean of -601.107 and a standard deviation of 6.336. There are nine distinct groups, and three of them exhibit distinct trends compared to the others. Specifically, the orange 'Dodd' group has a standard deviation difference of approximately 18% relative to the other groups, while the yellow 'documentary' group has an average difference of around 14%. Additionally, the orange 'Dies' group stands out with an average difference of about 11% compared to the others."</s>
# pred ["<s><summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot shows the distribution of values over time for 'variables_donations_finish'. Typically, the data in this chart has a mean of 195.338 and a standard deviation of 0.261. While there is drift, the values periodically return to their original mean. The chart includes four distinct groups, with one group (yellow 'The data') exhibiting a difference in amplitude of approximately 12% compared to the other groups."]
# answer <summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot displays the distribution of values over time for 'variables_donations_finish', showing a mean of 186.576 and a standard deviation of 0.434. While there is evidence of drift, the data periodically returns to its original value. There are five distinct groups present, with no other notable abnormalities.</s>
# pred ["<s><summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot shows the distribution of values over time for 'ko_regulation'. The data typically has a mean of -12.589 and a standard deviation of 0.318, and it appears to increase with a positive slope. There are five distinct groups visible in the chart, and one of them (the orange 'period' group) stands out with a slope difference of approximately 13% compared to the other groups."]
# answer <summarize_chart> describe this chart about trend and its abnormalities <s_answer> "This scatterplot shows the distribution of values over time for 'ko_障_modulation'. The data typically has a mean of -12.837 and a standard deviation of 0.201, and it exhibits a positive slope as it continues to increase. There are a total of 5 groups."</s>
# pred ["<s><summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot shows the relationship between 'honesty_county_harvest' and 'é_ Based on the given data, it appears that the mean of 'honesty_county_harvest' is -2124.925 with a standard deviation of 8.434, while the mean of 'é_ Based on' is -2.826 with a standard deviation of 0.83. There are a total of 9 groups, and the correlation coefficient between the two datasets is 0.018, indicating little to no linear relationship between them."]
# answer <summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot illustrates the relationship between 'honesty_county_harvest' and 'é_게', with data points representing means of -2129.04 and -3.031, respectively, and standard deviations of 16.249 and 1.204. There are a total of 8 groups, and the correlation coefficient is 0.039. Note that there is no strong linear relationship between the two data sets, as indicated by the relatively low correlation coefficient.</s>
# pred ['<s><summarize_chart> describe this chart about correlation and its abnormalities <s_answer> "According, there are seven groups in total, and the correlation coefficient is 0.013, indicating little to no linear relationship between the two datasets."']
# answer <summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot illustrates the relationship between 'tech_پ_Main' and 'nodes_技_define', with both sets of data representing means and standard deviations. The plot shows a total of 9 groups, and the correlation coefficient is -0.04, indicating no linear relationship between the two variables. The mean of 'tech_پ_Main' is approximately 670.877, while the standard deviation is around 6.572. Similarly, the mean of 'nodes_技_define' is approximately 785.624, with a standard deviation of roughly 186.663.</s>
# pred ["<s><summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot depicts the distribution of values over time for'meetup_ão', showcasing a typical mean of 2273.828 and a standard deviation of 10.046. The data exhibits an upward trend with a positive slope. There are nine distinct groups, each with its own unique pattern. Notably, the blue 'beach' group deviates from the others by approximately 10%, while the blue 'Size' group deviates by about 12%."]
# answer <summarize_chart> describe this chart about trend and its abnormalities <s_answer> This scatterplot shows the distribution of values over time for 'meetup_ão', with a mean of 2272.513 and a standard deviation of 26.351. There are a total of 8 groups, and one group, represented by the blue 'thin' line, has a distinct trend different from the other groups, with an average difference of approximately 19%.</s>
# pred ["<s><summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot shows the relationship between 'ario_scroll' and 'Enter_ line', with the data points representing the mean and standard deviation of each variable. The chart indicates a total of 9 groups, and the correlation coefficient of this scatter plot is 0.048. Since the correlation coefficient is less than 0.3, there is no strong linear relationship between the two data sets."]
# answer <summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot displays the relationship between 'ario_scroll' and 'Enter_ソ', with each point representing the average value of 9 groups. The mean of 'ario_scroll' is approximately 1041.2, with a standard deviation of around 191.06. Meanwhile, the mean of 'Enter_ソ' is roughly -66.77, with a standard deviation of about 56.91. There is little linear correlation between these two variables, as evidenced by the correlation coefficient of 0.128, which falls below 0.3.</s>
# pred ["<s><summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot depicts the relationship between 'premier_speaks' and'revenues_lads_garbage', with each data point representing a group of values. The mean values for 'premier_speaks' are around 57.701, while the standard deviation is approximately 0.258. Similarly, the mean values for'revenues_lads_garbage' are around 81.265, with a standard deviation of about 0.81. There are a total of 6 groups represented in this scatterplot. The correlation coefficient of this chart is -0.034, indicating little to no linear relationship between the two data sets."]
# answer <summarize_chart> describe this chart about correlation and its abnormalities <s_answer> This scatterplot depicts the relationship between 'premier_speaks' and 'revenues_lads_garbage', with a mean of 57.888 for 'premier_speaks' and a standard deviation of 0.261, while 'revenues_lads_garbage' has a mean of 81.271 and a standard deviation of 0.277. There are six groups in total, and the correlation coefficient is -0.032, indicating no strong linear relationship between the two datasets.</s>
